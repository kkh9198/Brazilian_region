# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
brazil_dataset = pd.read_csv('finaldf.csv')
order_reviews_dataset = pd.read_csv('olist_order_reviews_dataset.csv')

#널값을 빈값으로 변경
order_reviews_dataset['review_comment_title'] = order_reviews_dataset['review_comment_title'].fillna('')
order_reviews_dataset['review_comment_message'] = order_reviews_dataset['review_comment_message'].fillna('')

# %%
brazil_dataset = brazil_dataset.merge(order_reviews_dataset, on = 'order_id', how='left')
df = brazil_dataset.copy()
df.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'product_weight_g', 'product_length_cm', 'product_height_cm',
#        'product_width_cm', 'product_category_name_english',
#        'customer_zip_code_prefix', 'seller_zip_code_prefix',
#        'seller_geolocation_lat', 'seller_geolocation_lng',
#        'customer_geolocation_lat', 'customer_geolocation_lng', 'review_id',
#        'review_score', 'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %%
category_mean = df.groupby(['product_category_name_english']).mean()

# %%
print(category_mean)
# Out:
#                                order_item_id       price  freight_value  \
# product_category_name_english
# agro_industry_and_commerce          1.252427  342.553883      27.365049
# air_conditioning                    1.219512  185.100209      22.641533
# art                                 1.010471  121.334974      19.482251
# arts_and_craftmanship               1.086957   78.443913      15.497826
# audio                               1.047354  139.027047      15.765209
# ...                                      ...         ...            ...
# stationery                          1.103320   91.032440      18.583075
# tablets_printing_image              1.049383   90.498889      15.009012
# telephony                           1.124422   70.130393      15.665067
# toys                                1.067887  116.976240      18.840679
# watches_gifts                       1.093096  199.472781      16.759625
#
#                                product_weight_g  product_length_cm  \
# product_category_name_english
# agro_industry_and_commerce          3683.126214          28.936893
# air_conditioning                    4098.944251          38.783972
# art                                 1539.408377          49.513089
# arts_and_craftmanship               1417.826087          31.217391
# audio                               1211.771588          19.988858
# ...                                         ...                ...
# stationery                          2758.039004          35.105394
# tablets_printing_image               307.481481          25.543210
# telephony                            262.420675          18.362165
# toys                                1856.814645          30.623697
# watches_gifts                        584.821304          19.581939
#
#                                product_height_cm  product_width_cm  \
# product_category_name_english
# agro_industry_and_commerce             23.941748         21.014563
# air_conditioning                       21.132404         26.191638
# art                                     7.617801         37.052356
# arts_and_craftmanship                  11.086957         21.913043
# audio                                   9.476323         15.440111
# ...                                          ...               ...
# stationery                             21.741909         25.207469
# tablets_printing_image                  9.592593         23.271605
# telephony                               6.335800         13.380435
# toys                                   21.188660         24.687516
# watches_gifts                           8.822001         15.231869
#
#                                customer_zip_code_prefix  \
# product_category_name_english
# agro_industry_and_commerce                 32849.524272
# air_conditioning                           29295.665505
# art                                        31231.591623
# arts_and_craftmanship                      23461.217391
# audio                                      34224.384401
# ...                                                 ...
# stationery                                 35341.998340
# tablets_printing_image                     33820.135802
# telephony                                  39751.876503
# toys                                       34503.565472
# watches_gifts                              35832.408996
#
#                                seller_zip_code_prefix  seller_geolocation_lat  \
# product_category_name_english
# agro_industry_and_commerce               47700.480583              -24.646045
# air_conditioning                         33291.773519              -23.032706
# art                                      21443.172775              -23.314924
# arts_and_craftmanship                    18348.304348              -23.637867
# audio                                    11344.342618              -22.574798
# ...                                               ...                     ...
# stationery                               18291.833195              -22.951009
# tablets_printing_image                    9379.555556              -23.780418
# telephony                                12618.124191              -22.616936
# toys                                     23287.324434              -23.484372
# watches_gifts                            18130.240237              -22.869943
#
#                                seller_geolocation_lng  \
# product_category_name_english
# agro_industry_and_commerce                 -48.188809
# air_conditioning                           -48.071044
# art                                        -47.291073
# arts_and_craftmanship                      -47.023595
# audio                                      -47.118675
# ...                                               ...
# stationery                                 -46.686921
# tablets_printing_image                     -46.424147
# telephony                                  -46.147164
# toys                                       -46.802821
# watches_gifts                              -47.047850
#
#                                customer_geolocation_lat  \
# product_category_name_english
# agro_industry_and_commerce                   -20.876879
# air_conditioning                             -21.846312
# art                                          -21.132699
# arts_and_craftmanship                        -22.321681
# audio                                        -21.118430
# ...                                                 ...
# stationery                                   -21.160649
# tablets_printing_image                       -18.700578
# telephony                                    -20.156988
# toys                                         -21.227879
# watches_gifts                                -20.358527
#
#                                customer_geolocation_lng  review_score
# product_category_name_english
# agro_industry_and_commerce                   -46.301177      4.087379
# air_conditioning                             -46.245858      4.067376
# art                                          -46.204950      4.121693
# arts_and_craftmanship                        -46.285627      4.260870
# audio                                        -45.793888      3.830986
# ...                                                 ...           ...
# stationery                                   -46.230668      4.260434
# tablets_printing_image                       -45.505178      4.139241
# telephony                                    -46.137700      4.012331
# toys                                         -46.129080      4.229882
# watches_gifts                                -45.665404      4.099947
#
# [72 rows x 14 columns]

# %%
fig=plt.figure(figsize=(14,12))
sns.set_style("darkgrid")
sns.barplot(y=category_mean.index, x=category_mean['review_score'].sort_values())
plt.title('review_score_mean',fontsize=20)
# Out:
# Text(0.5, 1.0, 'review_score_mean')
